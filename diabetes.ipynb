# %%
import pandas as pd
import numpy as np
from scipy.stats import shapiro

# %%
df = pd.read_csv('/content/diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# 1. check the normalisy of all data set

# %%
stat,p = shapiro(df["Pregnancies"])
print(p)
if p > 0.05:
  print("Normal Distribution")
else:
  print("Not Normal Distribution")
# Out:
# 1.6092572358874225e-21
# Not Normal Distribution

# %%
stat1,p1 = shapiro(df["Glucose"])
print(p1)
if p1 > 0.05:
  print("Normal Distribution")
else:
  print("Not Normal Distribution")
# Out:
# 1.9863474999979633e-11
# Not Normal Distribution

# %%
stat2,p2 = shapiro(df["BloodPressure"])
print(p2)
if p2 > 0.05:
  print("Normal Distribution")
else:
  print("Not Normal Distribution")
# Out:
# 1.5841623290215717e-28
# Not Normal Distribution

# %%
stat3,p3 = shapiro(df["SkinThickness"])
print(p3)
if p3 > 0.05:
  print("Normal Distribution")
else:
  print("Not Normal Distribution")
# Out:
# 1.751754164091415e-21
# Not Normal Distribution

# %%
stat4,p4 = shapiro(df["Insulin"])
print(p4)
if p4 > 0.05:
  print("Normal Distribution")
else:
  print("Not Normal Distribution")
# Out:
# 7.914331939766787e-34
# Not Normal Distribution

# %%
stat5,p5 = shapiro(df["BMI"])
print(p5)
if p5 > 0.05:
  print("Normal Distribution")
else:
  print("Not Normal Distribution")
# Out:
# 1.8416516138516335e-15
# Not Normal Distribution

# %%
stat6,p6 = shapiro(df["DiabetesPedigreeFunction"])
print(p6)
if p6 > 0.05:
  print("Normal Distribution")
else:
  print("Not Normal Distribution")
# Out:
# 2.477505530854268e-27
# Not Normal Distribution

# %%
stat7,p7 = shapiro(df["Age"])
print(p7)
if p7 > 0.05:
  print("Normal Distribution")
else:
  print("Not Normal Distribution")
# Out:
# 2.4022741290400888e-24
# Not Normal Distribution

# %%
stat8,p8 = shapiro(df["Outcome"])
print(p8)
if p8 > 0.05:
  print("Normal Distribution")
else:
  print("Not Normal Distribution")
# Out:
# 1.2926899738528582e-38
# Not Normal Distribution

# %% [markdown]
# 2. find correlation of of all numeric columns with respect to dibeties pedigree function

# %%
from scipy.stats import pearsonr

# %%
r,p = pearsonr(df["DiabetesPedigreeFunction"],df["Pregnancies"])
print(r)
print(p)

if p > 0.05:
  print("Not Correlated")
else:
  print(" Correlated")
# Out:
# -0.033522672962613104
# 0.35353460198769926
# Not Correlated

# %%
r1,p1 = pearsonr(df["DiabetesPedigreeFunction"],df["Glucose"])
print(r1)
print(p1)

if p1 > 0.05:
  print("Not Correlated")
else:
  print("Correlated")
# Out:
# 0.1373372998283707
# 0.00013458781437157466
# Correlated

# %%
r2,p2 = pearsonr(df["DiabetesPedigreeFunction"],df["BloodPressure"])
print(r2)
print(p2)

if p2 > 0.05:
  print("Not Correlated")
else:
  print("Correlated")
# Out:
# 0.041264947930098585
# 0.2533743720192343
# Not Correlated

# %%
r3,p3 = pearsonr(df["DiabetesPedigreeFunction"],df["SkinThickness"])
print(r3)
print(p3)

if p3 > 0.05:
  print("Not Correlated")
else:
  print("Correlated")
# Out:
# 0.18392757295416323
# 2.8561794700267096e-07
# Correlated

# %%
r4,p4 = pearsonr  (df["DiabetesPedigreeFunction"],df["Insulin"])
print(r4)
print(p4)

if p4 > 0.05:
  print("Not Correlated")
else:
  print("Correlated")
# Out:
# 0.18507092916809909
# 2.4022640739424854e-07
# Correlated

# %%
r5,p5 = pearsonr(df["DiabetesPedigreeFunction"],df["BMI"])
print(r5)
print(p5)

if p5 > 0.05:
  print("Not Correlated")
else:
  print("Correlated")
# Out:
# 0.14064695254510517
# 9.197970126957359e-05
# Correlated

# %%
r6,p6 = pearsonr(df["DiabetesPedigreeFunction"],df["Age"])
print(r6)
print(p6)

if p6 > 0.05:
  print("Not Correlated")
else:
  print("Correlated")
# Out:
# 0.03356131243480553
# 0.3529797336668882
# Not Correlated

# %%
r7,p7 = pearsonr(df["DiabetesPedigreeFunction"],df["Outcome"])
print(r7)
print(p7)

if p7 > 0.05:
  print("Not Correlated")
else:
  print("Correlated")
# Out:
# 0.17384406565296007
# 1.2546070101487771e-06
# Correlated

# %% [markdown]
# 3. choose one column that has the highest correlation with the diabetes pedigree function and apply regression in order to predict the output value for a user input value.

# %%
x = df['Insulin'].sum()
y = df['DiabetesPedigreeFunction'].sum()
xy = x*y
xy

# %%
x_y_ = df['Insulin']*df['DiabetesPedigreeFunction']
xy_ = x_y_.sum()
xy_

# %%
xx = (df["Insulin"]**2).sum()
xx

# %%
x2 = (df["Insulin"].sum())**2
x2

# %%
n = len(df)
n

# %%
slope = (n*xy_ - xy)/(n*xx - x2)
slope
# Out:
# 0.0005320822748938753

# %%
intercept = (y - slope*x)/n
intercept
# Out:
# 0.42941641367298683

# %%
x = int(input("Enter x value: "))

y = slope*x + intercept
print(y)
